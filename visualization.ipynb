# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#df.info()

# %%
df=pd.read_csv('201905-baywheels-tripdata.csv')
df['start_time']=pd.to_datetime(df.start_time)
df['end_time']=pd.to_datetime(df.end_time)
df['start-day_of_week'] = df['start_time'].dt.weekday_name
df['end-day_of_week'] = df['end_time'].dt.weekday_name
df['start_day'] = df.start_time.apply(lambda x: x.day)
df['end_day'] = df.end_time.apply(lambda x: x.day)

df.user_type = df.user_type.astype('category')
df.member_gender = df.member_gender.astype('category')
df.bike_share_for_all_trip = df.bike_share_for_all_trip.astype('category')
df['member_age'] = 2019-df['member_birth_year']

df.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         48877 2019-05-31 20:34:56.811 2019-06-01 10:09:34.796
# 1         47050 2019-05-31 19:43:56.196 2019-06-01 08:48:06.919
# 2          5912 2019-05-31 23:54:24.089 2019-06-01 01:32:56.982
# 3          2629 2019-05-31 23:59:57.449 2019-06-01 00:43:46.874
# 4          4235 2019-05-31 23:05:48.932 2019-06-01 00:16:24.457
#
#    start_station_id              start_station_name  start_station_latitude  \
# 0             321.0                5th St at Folsom               37.780146
# 1             246.0           Berkeley Civic Center               37.869060
# 2             149.0            Emeryville Town Hall               37.831275
# 3             186.0          Lakeside Dr at 14th St               37.801319
# 4              34.0  Father Alfred E Boeddeker Park               37.783988
#
#    start_station_longitude  end_station_id        end_station_name  \
# ...

# %% [markdown]
# # UNIVARIATE EXPLORATION OF DATA

# %% [markdown]
# # what is the most  type of users?

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='user_type',data=df,alpha=0.7);
plt.title("count of user type");

# %% [markdown]
# # what is the distrbution of users gender?

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='member_gender',data=df,alpha=0.7);
plt.title('count of member gender');

# %% [markdown]
# # Depending on the days of the week, what is total of receving bykes?

# %%
base_color=sns.color_palette()[0]
ax = sns.countplot(x='start-day_of_week',  data=df,color=base_color)
plt.title('Weekly receving of bikes')
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='bike_share_for_all_trip',data=df,alpha=0.7);

# %%
df.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         48877 2019-05-31 20:34:56.811 2019-06-01 10:09:34.796
# 1         47050 2019-05-31 19:43:56.196 2019-06-01 08:48:06.919
# 2          5912 2019-05-31 23:54:24.089 2019-06-01 01:32:56.982
# 3          2629 2019-05-31 23:59:57.449 2019-06-01 00:43:46.874
# 4          4235 2019-05-31 23:05:48.932 2019-06-01 00:16:24.457
#
#    start_station_id              start_station_name  start_station_latitude  \
# 0             321.0                5th St at Folsom               37.780146
# 1             246.0           Berkeley Civic Center               37.869060
# 2             149.0            Emeryville Town Hall               37.831275
# 3             186.0          Lakeside Dr at 14th St               37.801319
# 4              34.0  Father Alfred E Boeddeker Park               37.783988
#
#    start_station_longitude  end_station_id        end_station_name  \
# ...

# %%
#df.hist();

# %%
#plt.xlabel('member_birth_year')
#plt.ylabel('member_gender')
#plt.title('Histogram of IQ')

# %% [markdown]
# # BIVARIATE EXPLORATION OF DATA

# %% [markdown]
# # What is the age of users compared to their gender?

# %%
ax = sns.stripplot(x="member_birth_year", y="member_gender", data=df)

# %%
#ax = sns.violinplot(x="member_birth_year", y="member_gender", data=df,inner=None, color=".8")
ax = sns.stripplot(x="member_birth_year", y="member_gender", data=df, jitter=True);

# %% [markdown]
# # what is the percentage of correlation between each variable?

# %%
plt.figure(figsize= (10,7))
sns.heatmap(df.corr(),annot=True);

# %%
#df.member_birth_year.unique()

# %%
#df['day_of_week'] = df['start_time'].dt.weekday_name

# %%
df.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         48877 2019-05-31 20:34:56.811 2019-06-01 10:09:34.796
# 1         47050 2019-05-31 19:43:56.196 2019-06-01 08:48:06.919
# 2          5912 2019-05-31 23:54:24.089 2019-06-01 01:32:56.982
# 3          2629 2019-05-31 23:59:57.449 2019-06-01 00:43:46.874
# 4          4235 2019-05-31 23:05:48.932 2019-06-01 00:16:24.457
#
#    start_station_id              start_station_name  start_station_latitude  \
# 0             321.0                5th St at Folsom               37.780146
# 1             246.0           Berkeley Civic Center               37.869060
# 2             149.0            Emeryville Town Hall               37.831275
# 3             186.0          Lakeside Dr at 14th St               37.801319
# 4              34.0  Father Alfred E Boeddeker Park               37.783988
#
#    start_station_longitude  end_station_id        end_station_name  \
# ...

# %%
#sns.boxplot(x="duration_sec", y="member_birth_year", hue="user_type", data=df, palette="PRGn")

# %%
df.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         48877 2019-05-31 20:34:56.811 2019-06-01 10:09:34.796
# 1         47050 2019-05-31 19:43:56.196 2019-06-01 08:48:06.919
# 2          5912 2019-05-31 23:54:24.089 2019-06-01 01:32:56.982
# 3          2629 2019-05-31 23:59:57.449 2019-06-01 00:43:46.874
# 4          4235 2019-05-31 23:05:48.932 2019-06-01 00:16:24.457
#
#    start_station_id              start_station_name  start_station_latitude  \
# 0             321.0                5th St at Folsom               37.780146
# 1             246.0           Berkeley Civic Center               37.869060
# 2             149.0            Emeryville Town Hall               37.831275
# 3             186.0          Lakeside Dr at 14th St               37.801319
# 4              34.0  Father Alfred E Boeddeker Park               37.783988
#
#    start_station_longitude  end_station_id        end_station_name  \
# ...

# %% [markdown]
# # over the month, what is the most of users type usage of bikes system?

# %%
plt.figure(figsize=(10,7))
sns.countplot(data = df, x = 'start_day', hue = 'user_type')
plt.title('monthly usage of bike system ',fontsize = 14)
plt.xlabel('month',fontsize = 14)
plt.ylabel('count of bike rides',fontsize = 14)
plt.xticks(rotation=75);

# %%
color = sns.color_palette("viridis")[1]

sns.countplot(x = "start_station_id", data = df, color = color);

# %% [markdown]
# # show us the start station of bikyes on the map

# %%
fig = df.plot(kind="scatter", x="start_station_longitude", y="start_station_latitude", alpha=0.6,
figsize=(18,11), cmap=plt.get_cmap("inferno"),c="start_station_id", colorbar=True,)

# %% [markdown]
# # What are the most visited start stations in the cycling system?

# %%
top_15 = df.start_station_id.value_counts().iloc[:15]

fig, ax = plt.subplots(figsize = (20,5), dpi = 80)
color = sns.color_palette("viridis")[1]
sns.countplot(x = "start_station_id", data = df, order=top_15.index, color = color);
plt.title("Top 15 Start Stations");

# %%
df.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         48877 2019-05-31 20:34:56.811 2019-06-01 10:09:34.796
# 1         47050 2019-05-31 19:43:56.196 2019-06-01 08:48:06.919
# 2          5912 2019-05-31 23:54:24.089 2019-06-01 01:32:56.982
# 3          2629 2019-05-31 23:59:57.449 2019-06-01 00:43:46.874
# 4          4235 2019-05-31 23:05:48.932 2019-06-01 00:16:24.457
#
#    start_station_id              start_station_name  start_station_latitude  \
# 0             321.0                5th St at Folsom               37.780146
# 1             246.0           Berkeley Civic Center               37.869060
# 2             149.0            Emeryville Town Hall               37.831275
# 3             186.0          Lakeside Dr at 14th St               37.801319
# 4              34.0  Father Alfred E Boeddeker Park               37.783988
#
#    start_station_longitude  end_station_id        end_station_name  \
# ...

# %% [markdown]
# # what is the weekly usage of bike system over users type?

# %%
sns.countplot(data=df, x='start-day_of_week', hue="user_type")
plt.title('weekly usage of bike system',fontsize = 14)
plt.xlabel('week',fontsize = 14)
plt.ylabel('count of rides',fontsize = 14);
plt.xticks(rotation=45);

# %%
#sns.relplot(x="duration_sec", y="member_birth_year", hue="user_type", style="member_gender", data=df);

# %% [markdown]
# # MULTIVARIATE EXPLORATION OF DATA

# %% [markdown]
# # what is relation between member gender and member type and duration over thier ages?

# %%
sns.relplot(x="member_birth_year", y="duration_sec", hue="user_type", style="member_gender", data=df);

# %%
g = sns.catplot(x="user_type", y="member_birth_year", hue="member_gender",data=df, kind="strip",jitter=True,height=4, aspect=.7);

# %% [markdown]
# # what is relation between  days of week and duration over the age?

# %%
sns.relplot(x="member_birth_year", y="duration_sec", hue="start-day_of_week",data=df);

# %%
plt.subplots(figsize=(12,10))
sns.barplot(data = df[df['user_type']=='Subscriber'],
                  x='member_birth_year', y='duration_sec', hue='member_gender',
                  palette='YlGnBu')
plt.xticks(rotation=90);

# %%
plt.subplots(figsize=(12,10))
sns.barplot(data = df[df['user_type']=='Customer'],
                  x='member_birth_year', y='duration_sec', hue='member_gender',
                  palette='YlGnBu')
plt.xticks(rotation=90);

# %%
sns.relplot(x="member_birth_year", y="duration_sec", hue="start-day_of_week",height=7,linewidth=5 ,kind="line", estimator=None, 
            data=df.query('member_birth_year > 1970'));

# %%
df.member_birth_year.value_counts()
# Out:
# 1989.0    9566
# 1988.0    9064
# 1992.0    9014
# 1991.0    8881
# 1990.0    8865
# 1993.0    8555
# 1994.0    8222
# 1987.0    8011
# 1995.0    7469
# 1986.0    7156
# 1985.0    6694
# 1984.0    6336
# 1996.0    5461
# 1983.0    5416
# 1982.0    4968
# 1980.0    4718
# 1981.0    4591
# 1979.0    3481
# 1977.0    3208
# 1978.0    2955
# 1997.0    2905
# 1974.0    2577
# 1998.0    2442
# 1975.0    2432
# 1976.0    2355
# 1973.0    2301
# 1970.0    2237
# 1968.0    2145
# 1971.0    2144
# 1972.0    1827
#           ...
# 1953.0     168
# 1951.0     160
# 1949.0     154
# 1931.0     141
# 1947.0     118
# 1952.0      96
# 1945.0      94
# 1948.0      82
# 2001.0      57
# 1942.0      46
# 1900.0      31
# 1943.0      29
# 1941.0      25
# 1920.0      22
# 1946.0      19
# 1896.0      18
# 1902.0      12
# 1944.0      12
# 1935.0       8
# 1927.0       7
# 1939.0       6
# 1933.0       4
# 1904.0       4
# 1932.0       2
# 1934.0       1
# 1930.0       1
# 1928.0       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182163 entries, 0 to 182162
# Data columns (total 21 columns):
# duration_sec               182163 non-null int64
# start_time                 182163 non-null datetime64[ns]
# end_time                   182163 non-null datetime64[ns]
# start_station_id           182148 non-null float64
# start_station_name         182148 non-null object
# start_station_latitude     182163 non-null float64
# start_station_longitude    182163 non-null float64
# end_station_id             182148 non-null float64
# end_station_name           182148 non-null object
# end_station_latitude       182163 non-null float64
# end_station_longitude      182163 non-null float64
# bike_id                    182163 non-null int64
# user_type                  182163 non-null category
# member_birth_year          173694 non-null float64
# member_gender              173697 non-null category
# bike_share_for_all_trip    182163 non-null category
# ...

# %% [markdown]
# # what is the most visitor end station?

# %%
end_station_name=df.end_station_name.value_counts()
end_station_name.head().plot(kind='barh', figsize = (10, 5))
plt.title('Most visited end stations',fontsize = 14)
plt.ylabel('count of rides',fontsize = 14)
plt.xlabel('station name',fontsize = 14);

# %%
sns.countplot(data=df,x='end-day_of_week')
plt.title('Weekly delivery of bikes',fontsize = 14)
plt.ylabel('count of rides',fontsize = 14)
plt.xlabel('week',fontsize = 14)
plt.xticks(rotation=45);

# %%
#g = sns.PairGrid(df, hue="user_type")
#g = g.map_diag(plt.hist)
#g = g.map_offdiag(plt.scatter)
#g = g.add_legend()

# %%
g = sns.PairGrid(df, hue="user_type",vars=["member_age", "duration_sec"]);
g = g.map_diag(sns.violinplot)
g = g.map_offdiag(plt.scatter)
g = g.add_legend();

# %%
g = sns.pairplot(df, height=3,vars=["member_age", "duration_sec"]);
# Out:
# C:\Users\mooqa\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\mooqa\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
